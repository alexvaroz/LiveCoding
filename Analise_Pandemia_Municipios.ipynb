# %% [markdown]
# ### Título

# %%
# Importação das bibliotecas
import pandas as pd

# %%
df = pd.read_csv('caso.csv')

# %%
df.head()
# Out:
#          date state city place_type  confirmed  deaths  order_for_place  \
# 0  2020-05-03    SE  NaN      state        730      14               40
# 1  2020-05-02    SE  NaN      state        601      14               39
# 2  2020-05-01    SE  NaN      state        517      14               38
# 3  2020-04-30    SE  NaN      state        453      14               37
# 4  2020-04-28    SE  NaN      state        280      11               36
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                  2298696.0            28.0
# 1    False                  2298696.0            28.0
# 2    False                  2298696.0            28.0
# 3    False                  2298696.0            28.0
# 4    False                  2298696.0            28.0
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                        31.75714      0.0192
# 1                        26.14526      0.0233
# 2                        22.49101      0.0271
# ...

# %%
df.shape
# Out:
# (49109, 12)

# %%
df.columns
# Out:
# Index(['date', 'state', 'city', 'place_type', 'confirmed', 'deaths',
#        'order_for_place', 'is_last', 'estimated_population_2019',
#        'city_ibge_code', 'confirmed_per_100k_inhabitants', 'death_rate'],
#       dtype='object')

# %%
df["place_type"].value_counts()
# Out:
# city     47753
# state     1356
# Name: place_type, dtype: int64

# %%
df.count()
# Out:
# date                              49109
# state                             49109
# city                              47753
# place_type                        49109
# confirmed                         49109
# deaths                            49109
# order_for_place                   49109
# is_last                           49109
# estimated_population_2019         48501
# city_ibge_code                    48501
# confirmed_per_100k_inhabitants    47520
# death_rate                        49109
# dtype: int64

# %%
df.sort_values(by = 'date', ascending = False)
# Out:
#              date state                       city place_type  confirmed  \
# 30903  2020-05-04    MS                        NaN      state        274
# 36275  2020-05-04    MG                   Alterosa       city          1
# 22659  2020-05-04    PR       Planaltina do Paraná       city          7
# 36294  2020-05-04    MG                   Araguari       city          9
# 22675  2020-05-04    PR               Ponta Grossa       city         19
# 4010   2020-05-04    RS  Santo Antônio da Patrulha       city          2
# 22720  2020-05-04    PR             Prado Ferreira       city          3
# 22727  2020-05-04    PR           Primeiro de Maio       city          2
# 22756  2020-05-04    PR                   Quatiguá       city          2
# 36283  2020-05-04    MG               Além Paraíba       city          7
# 22794  2020-05-04    PR              Quatro Barras       city          2
# 36281  2020-05-04    MG             Alto Jequitibá       city          1
# ...

# %%
# Deletar uma coluna
df.drop(columns = 'city_ibge_code', inplace = True)

# %%
df.columns
# Out:
# Index(['date', 'state', 'city', 'place_type', 'confirmed', 'deaths',
#        'order_for_place', 'is_last', 'estimated_population_2019',
#        'confirmed_per_100k_inhabitants', 'death_rate'],
#       dtype='object')

# %%
df[df["date"] == '2020-05-04']
# Out:
#              date state                     city place_type  confirmed  \
# 1098   2020-05-04    RS                      NaN      state       1768
# 1151   2020-05-04    RS                Ajuricaba       city          1
# 1173   2020-05-04    RS                 Alegrete       city          1
# 1207   2020-05-04    RS                 Alvorada       city         14
# 1254   2020-05-04    RS               Anta Gorda       city          2
# 1296   2020-05-04    RS           Arroio do Meio       city         12
# 1312   2020-05-04    RS            Arroio do Sal       city          2
# 1342   2020-05-04    RS         Arroio dos Ratos       city          3
# 1369   2020-05-04    RS              Arvorezinha       city          1
# 1379   2020-05-04    RS                     Bagé       city         29
# 1426   2020-05-04    RS            Barros Cassal       city          1
# 1429   2020-05-04    RS          Bento Gonçalves       city         65
# ...

# %%
df[(df['city'] == 'Luziânia')]
# Out:
#              date state      city place_type  confirmed  deaths  \
# 33886  2020-05-03    GO  Luziânia       city         13       3
# 33887  2020-05-02    GO  Luziânia       city         13       3
# 33888  2020-05-01    GO  Luziânia       city         13       3
# 33889  2020-04-30    GO  Luziânia       city         13       3
# 33890  2020-04-29    GO  Luziânia       city         13       3
# 33891  2020-04-28    GO  Luziânia       city         13       3
# 33892  2020-04-27    GO  Luziânia       city         11       3
# 33893  2020-04-26    GO  Luziânia       city         11       2
# 33894  2020-04-25    GO  Luziânia       city         11       2
# 33895  2020-04-24    GO  Luziânia       city          9       2
# 33896  2020-04-23    GO  Luziânia       city          9       2
# 33897  2020-04-22    GO  Luziânia       city          9       2
# 33898  2020-04-21    GO  Luziânia       city          9       2
# 33899  2020-04-20    GO  Luziânia       city         10       2
# ...

# %%
# Mortos no estado de GO, 850
df[(df["state"] == 'GO') & (df['date'] == '2020-05-03') & (df["city"].isna())]
# Out:
#              date state city place_type  confirmed  deaths  order_for_place  \
# 32959  2020-05-03    GO  NaN      state        850      30               53
#
#        is_last  estimated_population_2019  confirmed_per_100k_inhabitants  \
# 32959     True                  7018354.0                         12.1111
#
#        death_rate
# 32959      0.0353

# %%
# Mortos no estado de GO, somando a quantidade dos municípios
df[(df["state"] == 'GO') & (df['date'] == '2020-05-03') & (df["city"].notna())]['confirmed'].sum()
# Out:
# 850

# %%
# Verificar entre as cidades com menos de 100.000 habitantes, qual a que registrou mais casos
df[df['estimated_population_2019'] <= 100000].sort_values('confirmed', ascending = False).head(1)
# Out:
#              date state        city place_type  confirmed  deaths  \
# 47865  2020-05-03    AM  Manacapuru       city        551      33
#
#        order_for_place  is_last  estimated_population_2019  \
# 47865               38     True                    97377.0
#
#        confirmed_per_100k_inhabitants  death_rate
# 47865                       565.84204      0.0599
